# %% [markdown]
# <a href="https://colab.research.google.com/github/mukedon/python_studies/blob/main/tutorials/2_tutorial_strings_%26_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Strings
# They account for texts in the code and they can be used for myriad of cases; input, outputs, ...
#
# * They can be entered via `''` or `""`.

# %%
"""
'' or "" give the same output.
Inside '' or "" letters, punctuation (.?!...)
symbols (* & % @ ...) numbers (123...) can be entered
(for numbers they lose they integer, float, ... abilities)
"""
print('cat')
print("cat")
# Out:
# cat
# cat

# %%
print(1 + 2)
# Out:
# 3

# %%
print('1' + '2')
# Out:
# 12

# %% [markdown]
# It is obvious that, in the first print python sums up two integers meanwhile in the second print it takes them as strings and sums up these strings as putting them side by side in output.
#
# * print(1 + 2): integers → `addition`
# * print('1' + '2'): strings → `concatenation`

# %%
print(1 + '2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7942/3905401405.py in <cell line: 0>()
# ----> 1 print(1 + '2')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# As expected, summation of integer and string is not supported, because they belong to different class types and hence it give TypeError (here for mixing different types for the given function `print`).

# %%
type(1)
# Out:
# int

# %%
type('2 ')
# Out:
# str

# %%
print(00123)
# Out:
#   File "/tmp/ipykernel_7942/635555801.py", line 1
#     print(00123)
#           ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# Here python sees $00123$ as integer and as we know $00123$ is not an integer (at least in the sense that is defined in python) and hence outputs a SyntaxError.

# %%
print('00123')
# Out:
# 00123

# %% [markdown]
# Here we again used $00123$ and no error is face, because this time it defined as string and for string a number $00123$ is not a problem for python.

# %%
print('Bob's cat')
# Out:
#   File "/tmp/ipykernel_7942/505647650.py", line 1
#     print('Bob's cat')
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Bob's cat")
# Out:
# Bob's cat

# %% [markdown]
# By the two examples above using `''` for one item is more suitable, meanwhile for more than one item `""` is more convenient.

# %% [markdown]
# ## Variables
#
# Data storages.

# %%
# Storing data: "Kemal" into variable: my_name
my_name = "Kemal"
my_name
# Out:
# 'Kemal'

# %% [markdown]
# We stored data string: Kemal into reusable variable: my_name.

# %%
my_name.upper()
# Out:
# 'KEMAL'

# %% [markdown]
# We used upper case method: `uppper()` upper case the data in variable: my_name.

# %%
type(my_name)
# Out:
# str

# %% [markdown]
# `type` function can also be used for checking the data type of a variable.

# %%
my_age = 22
my_age
# Out:
# 22

# %%
type(my_age)
# Out:
# int

# %%
my_age = 23
my_age
# Out:
# 23

# %% [markdown]
# Because variable: my_age is not set, it can be changed by redefining it again and again.

# %%
fav_cities = ["Jena", "Erfurt", "Bamberg"]
fav_cities
# Out:
# ['Jena', 'Erfurt', 'Bamberg']

# %% [markdown]
# Here we defined variable: fav_cities out of a list, which means it contains more than one item/data in it.

# %% [markdown]
# ### Python Variable Naming Rules
# 1. Variable names cannot **start** wit numbers.
# 2. Only letters, number, and underscores (_) can be used.
# 3. Spaces are not allowed in variable names.
# 4. Variable names are **case** sensitive.
