# %% [markdown]
# <a href="https://colab.research.google.com/github/mukedon/python_studies/blob/main/tutorials/10_tutorial_functions_ui_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Functions
# `def` my_function(Parameters):
#
#         code
#
#         return value

# %%
def calc_rect_area(length, width):
  area = length * width
  print(area)

calc_rect_area(5, 2)
# Out:
# 10

# %%
# Global Name space
unit = 'feet squared'

def calc_rect_area(length, width):
  area = length * width
  return area

# Local Namespace: length, width, area
area = calc_rect_area(5, 2)

print(area, unit)
# Out:
# 10 feet squared

# %%
# Global Name space
unit = 'feet squared'
area = 200

def calc_rect_area(length, width):
  area = length * width
  return area

# Local Namespace: length, width, my_area
my_area = calc_rect_area(5, 2)

print(my_area, unit)
print(area)
# Out:
# 10 feet squared
# 200

# %% [markdown]
# ## User Input

# %%
name = input('Enter your name: ')
print("Hello", name)
# Out:
# Enter your name: Kemal
# Hello Kemal

# %%
number_1 = input("Enter 1st number: ")
number_2 = input("Enter 2nd number: ")

print("Sum", number_1 + number_2)
# Out:
# Enter 1st number: 1
# Enter 2nd number: 2
# Sum 12

# %%
number_1 = float(input("Enter 1st number: "))
number_2 = float(input("Enter 2nd number: "))

print("Sum", number_1 + number_2)
# Out:
# Enter 1st number: 1
# Enter 2nd number: 2
# Sum 3.0

# %% [markdown]
# ### Error Handling

# %%
numerator = float(input("Enter numerator: "))
denominator = float(input("Enter denominator: "))
quotient = numerator / denominator
print(f"The quotient is {quotient}.")
# Out:
# Enter numerator: 1
# Enter denominator: 2
# The quotient is 0.5.

# %%
try:
  numerator = float(input("Enter numerator: "))
  denominator = float(input("Enter denominator: "))
  quotient = numerator / denominator
  print(f"The quotient is {quotient}.")
except:
  print("Invalid input. Please enter a number.")
# Out:
# Enter numerator: 1
# Enter denominator: ger
# Invalid input. Please enter a number.

# %%
try:
  numerator = float(input("Enter numerator: "))
  denominator = float(input("Enter denominator: "))
  quotient = numerator / denominator
  print(f"The quotient is {quotient}.")
except ValueError:
  print("Invalid input. Please enter a number.")
except ZeroDivisionError:
  print()
# Out:
# Enter numerator: 1
# Enter denominator: gre
# Invalid input. Please enter a number.
