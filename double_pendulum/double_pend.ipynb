# %% [markdown]
# # Double pendulum

# %% [markdown]
# <img src="doub_pen.png" width="340" height="460" style="display: block; margin-left: auto; margin-right: auto; border-radius: 8px;" />
# <div style="text-align: center; margin-top: 10px;"><b><i>Double pendulum</i></b></div>
